# %%
from PIL import Image 
img_regression  = Image.open("image/regression.png")

# %%
img_regression
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=353x259 at 0x7F8B638774A8>

# %%
from PIL import Image 
neural_network  = Image.open("image/nn.png")

# %%
neural_network
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1318x862 at 0x7F8B63877940>

# %%
"""
Regression on Protein Tertiary Structure
using deep learning (Keras)
"""

# Data source: http://archive.ics.uci.edu/ml/datasets/Physicochemical+Properties+of+Protein+Tertiary+Structure
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4321859/
# http://www.mecs-press.org/ijmsc/ijmsc-v2-n2/IJMSC-V2-N2-3.pdf

import pandas as pd
import numpy as np
import warnings


warnings.filterwarnings("ignore")

def extract_data(path):
    data_frame = pd.read_csv(path, sep=",")
    return data_frame

def create_features_target(data_frame):
    target = data_frame[["RMSD"]]
    features = data_frame.drop("RMSD", axis=1)
    return features, target

d_frame = extract_data("data/casp_regression.csv")
data_features, data_target = create_features_target(d_frame)
data_features = data_features
print("Complete data")
print(d_frame.shape)
print()
print("Features")
print(data_features.shape)
print()
print("Target")
print(data_target.shape)
# Out:
# Complete data
# (45730, 10)
#
# Features
# (45730, 9)
#
# Target
# (45730, 1)

# %%
d_frame
# Out:
#          RMSD        F1       F2       F3        F4            F5        F6  \
# 0      17.284  13558.30  4305.35  0.31754  162.1730  1.872791e+06  215.3590
# 1       6.021   6191.96  1623.16  0.26213   53.3894  8.034467e+05   87.2024
# 2       9.275   7725.98  1726.28  0.22343   67.2887  1.075648e+06   81.7913
# 3      15.851   8424.58  2368.25  0.28111   67.8325  1.210472e+06  109.4390
# 4       7.962   7460.84  1736.94  0.23280   52.4123  1.021020e+06   94.5234
# 5       1.700   5117.30  1120.99  0.21905   51.6732  6.727227e+05   79.5911
# 6       9.314   5924.16  1625.27  0.27434   70.2103  8.285145e+05   76.8064
# 7       1.985   6882.15  1791.22  0.26027   77.2501  9.165165e+05   96.6785
# 8       1.915  12090.00  4190.74  0.34662  129.0020  1.687508e+06  186.3090
# 9       1.495   7400.24  1881.95  0.25430   82.9320  1.023846e+06  104.6970
# 10     12.118   6556.77  1612.77  0.24597   71.6315  8.915443e+05   93.5329
# 11      0.884   8828.21  2658.63  0.30115   90.8578  1.233384e+06  123.6860
# 12      7.913   5637.37  2665.83  0.47288   49.8566  7.716355e+05   95.7431
# 13     14.103   9021.10  3097.91  0.34340   98.1155  1.244160e+06  121.3480
# 14      6.581  17572.20  5226.42  0.29742  227.7690  2.434431e+06  296.8000
# 15      6.110  12330.60  4380.20  0.35523  195.9300  1.710155e+06  232.1540
# 16      1.339   8478.55  2206.94  0.26029   91.5054  1.199770e+06  128.1660
# 17      2.554   9147.09  2828.26  0.30919  104.0500  1.291447e+06  131.3580
# 18      3.805   3905.51  1102.49  0.28229   34.2034  5.643988e+05   48.1646
# 19     18.645  15620.90  5834.18  0.37348  153.4760  2.184645e+06  251.2250
# 20      8.114  18679.00  5966.18  0.31940  179.7570  2.650897e+06  268.6610
# 21     18.404  13605.50  4766.37  0.35032  139.7930  1.925985e+06  182.1950
# 22     19.379   8693.56  3265.99  0.37567   55.4973  1.258363e+06  126.9280
# 23     17.598   7727.36  1370.27  0.17732   77.5656  1.035614e+06  103.1770
# 24     16.102   8865.32  3317.32  0.37419   95.8075  1.223688e+06  122.7480
# 25     14.923   8259.29  2719.28  0.32923   76.1237  1.087133e+06  122.1430
# 26      1.655   7136.22  2645.28  0.37068   64.1673  1.032920e+06   93.2759
# 27      4.128   6922.15  2143.02  0.30958   63.6012  9.896310e+05   91.6472
# 28      1.477   6449.78  1439.30  0.22315   74.7722  8.497845e+05   90.5322
# 29      2.165  13274.30  3989.12  0.30051  169.7460  1.855448e+06  198.6440
# ...       ...       ...      ...      ...       ...           ...       ...
# 45700   0.966  23403.50  5511.79  0.23551  319.1290  3.224178e+06  407.9570
# 45701   5.546  18403.60  4882.31  0.26529  245.5710  2.559338e+06  294.5570
# 45702   3.581  13696.00  4088.79  0.29853  145.3500  1.844331e+06  211.9420
# 45703   1.661   6405.36  2182.59  0.34074   72.0344  8.836039e+05   92.7146
# 45704  18.522  10840.30  5689.76  0.52487   85.2052  1.355167e+06  207.9200
# 45705  18.875  11215.80  3814.74  0.34012  102.4110  1.537030e+06  179.7740
# 45706  17.150   9779.31  3687.08  0.37702   82.2241  1.397476e+06  144.7080
# 45707  13.678   6233.61   846.29  0.13576   52.7953  8.656223e+05   71.4992
# 45708   4.758   6458.52  1380.97  0.21382   64.5865  8.980187e+05   72.4505
# 45709   1.788   6226.42  1551.74  0.24921   67.6087  8.793935e+05   74.1427
# 45710   3.509  13867.40  4320.27  0.31154  167.1120  1.923652e+06  216.2990
# 45711   1.572   8716.67  2369.97  0.27188   83.0696  1.222297e+06  116.8790
# 45712   8.221   9893.75  2426.80  0.24528   87.7843  1.396274e+06  124.5970
# 45713  12.684   7353.75  2471.99  0.33615   50.5474  1.047082e+06  107.5370
# 45714  17.180   9616.40  3410.33  0.35463   99.8179  1.353932e+06  150.5450
# 45715   0.984   9725.16  1990.64  0.20468  104.3870  1.372349e+06  138.4390
# 45716   3.619  10153.40  3390.35  0.33391   83.1698  1.410026e+06  154.4500
# 45717  13.697   6074.87  1322.94  0.21777   56.0178  8.186789e+05   70.0644
# 45718  11.283   3781.01  1149.39  0.30399   36.0219  5.128434e+05   47.6737
# 45719   4.540   5080.14   845.89  0.16650   54.8128  6.682106e+05   56.3293
# 45720  17.595   9583.84  2456.51  0.25631   57.4054  1.358302e+06  107.4720
# 45721  13.104  17178.30  5525.77  0.32167  159.8850  2.451261e+06  246.7130
# 45722  17.435   8651.89  3892.56  0.44990   87.6646  1.055050e+06  157.2490
# 45723   5.652  10345.10  3101.21  0.29977  105.9130  1.481496e+06  147.1010
# 45724  11.354   9106.35  2553.61  0.28042   72.1356  1.231680e+06  124.9890
# 45725   3.762   8037.12  2777.68  0.34560   64.3390  1.105797e+06  112.7460
# 45726   6.521   7978.76  2508.57  0.31440   75.8654  1.116725e+06  102.2770
# 45727  10.356   7726.65  2489.58  0.32220   70.9903  1.076560e+06  103.6780
# 45728   9.791   8878.93  3055.78  0.34416   94.0314  1.242266e+06  115.1950
# 45729  18.827  12732.40  4444.36  0.34905  157.6300  1.788897e+06  229.4590
#
#             F7   F8       F9
# 0      4287.87  102  27.0302
# 1      3328.91   39  38.5468
# 2      2981.04   29  38.8119
# 3      3248.22   70  39.0651
# 4      2814.42   41  39.9147
# 5      3234.21   15  41.2382
# 6      2821.40   70  39.4964
# 7      3490.88   74  37.4203
# 8      4262.78   39  30.3916
# 9      3852.40   26  35.4140
# 10     3161.33   76  38.0433
# 11     3194.30   22  37.2413
# 12     2177.61    7  41.5268
# 13     3396.40   32  37.0667
# 14     4876.00  122  26.8169
# 15     4321.41  164  30.4491
# 16     3996.13  164  33.5263
# 17     3595.69   17  35.5938
# 18     1834.36   13  44.5123
# 19     5441.50  101  26.0101
# 20     6149.89  213  23.8081
# 21     4672.34  112  26.4540
# 22     4890.54   15  36.3849
# 23     3130.45   27  37.1829
# 24     3509.39   38  36.7233
# 25     3763.75   58  35.5364
# 26     3213.99   28  34.6186
# 27     3146.95   31  38.8427
# 28     3393.06   80  38.2100
# 29     5089.76   67  26.6638
# ...        ...  ...      ...
# 45700  6223.57  154  19.8365
# 45701  5457.64  215  25.6038
# 45702  4993.11   53  28.1334
# 45703  3203.00   37  40.2693
# 45704  2954.30   70  38.2021
# 45705  4316.51  105  34.1568
# 45706  4094.08   69  31.6338
# 45707  2733.96   45  34.9193
# 45708  3220.17   34  38.0233
# 45709  3131.57   14  38.9950
# 45710  4917.21   72  28.5099
# 45711  4092.53   49  33.9539
# 45712  3957.71  153  33.4454
# 45713  2965.32   68  39.5696
# 45714  4188.42   60  35.1050
# 45715  4324.37   50  30.6403
# 45716  3871.40   33  34.1444
# 45717  2471.63   38  41.4740
# 45718  1391.45   32  44.4733
# 45719  2698.52   57  38.6640
# 45720  4660.71   76  34.3923
# 45721  5642.11  129  24.2395
# 45722  2374.80   87  40.1504
# 45723  4492.04  101  31.3618
# 45724  4440.33   90  36.7669
# 45725  3384.21   84  36.8036
# 45726  3974.52   54  36.0470
# 45727  3290.46   46  37.4718
# 45728  3421.79   41  35.6045
# 45729  4626.85  141  29.8118
#
# [45730 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split

# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html#sklearn.model_selection.train_test_split

# divide the entire dataset into training and test sets
# learn on training set and evaluate the trained model on test set
test_size = 0.33
data_features_train, data_features_test, data_target_train, data_target_test = train_test_split(data_features, 
    data_target, test_size=test_size, random_state=42)

# shapes of the datasets
print("Size of training set")
print(data_features_train.shape)
print(data_target_train.shape)
print()
print("Size of test set")
print(data_features_test.shape)
print(data_target_test.shape)
# Out:
# Size of training set
# (30639, 9)
# (30639, 1)
#
# Size of test set
# (15091, 9)
# (15091, 1)

# %%
# Define a neural network using Keras deep learning library and optimize its parameter using Hyperopt
# https://keras.io/
# https://github.com/hyperopt/hyperopt/wiki/FMin

from keras.models import Sequential, Model
from keras.layers.core import Dropout, Activation, Dense
from keras.layers import Input
from keras.optimizers import RMSprop
from keras.callbacks import EarlyStopping, Callback
from sklearn.preprocessing import label_binarize
from sklearn.metrics import mean_squared_error

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials


# set dimensions
input_dimensions = data_features_train.shape[1]

# maximum number of epochs per sample evaluation
n_epochs = 10

# type of error function
loss_type = 'mean_squared_error'

# maxinum number of sample evaluations
max_evals = 20

# set initial ranges for parameters for hyperparameter optimisation
# number of iterations within one epoch = #_training_samples / batch_size
batch_size = [30, 300] # https://towardsdatascience.com/epoch-vs-iterations-vs-batch-size-4dfb9c7ce9c9

# output function for each layer
hidden_activation = ['tanh', 'relu', 'elu'] # https://keras.io/activations/
# https://towardsdatascience.com/exploring-activation-functions-for-neural-networks-73498da59b02

# number of neurons for each layer
hidden_units = [20, 300]
# https://stackoverflow.com/questions/44747343/keras-input-explanation-input-shape-units-batch-size-dim-etc

def create_model(params):
    
    # https://keras.io/getting-started/sequential-model-guide/
    # create network
    # input layer
    inputs = Input(shape=(input_dimensions,))
    
    # first hidden layer
    x = Dense(int(params["hidden_units"]), activation=params["hidden_activation"])(inputs)
    
    # dropout layer to avoid overfitting
    x = Dropout(params["dropout"])(x)
    
    # second dense layer
    x = Dense(int(params["hidden_units"]), activation=params["hidden_activation"])(x)
    
    # dropout layer to avoid overfitting
    x = Dropout(params["dropout"])(x)
    
    # output dense layer
    predictions = Dense(1, activation='linear')(x)
    
    # assign the inputs and output to the model
    model = Model(inputs=inputs, outputs=predictions)
    
    # create an optimizer object
    optimizer = RMSprop(lr=params["learning_rate"])
    
    # add optimizer and loss type to the model and compile it
    model.compile(optimizer=optimizer, loss=loss_type)
    
    print("==================================================================================")
    print("New model configuration")
    print("==================================================================================")
    
    model.summary()
    
    # stop training iteration as the error stops dropping
    # https://keras.io/callbacks/#callback
    # https://keras.io/callbacks/#earlystopping
    early_stopping = EarlyStopping(monitor='val_loss', mode='min', verbose=0, patience=2, min_delta=1e-4)
    
    # train the model using the training data and compute error on validation data
    model_fit = model.fit(data_features_train, data_target_train,
                          validation_data=(data_features_test, data_target_test),
                          epochs=n_epochs,
                          verbose=2,
                          batch_size=int(params["batch_size"]),
                          callbacks=[early_stopping])
    
    # predict on test data using trained model
    prediction = model.predict(data_features_test)
    
    # compute error between true values and predicted values
    mse = mean_squared_error(prediction, data_target_test)
    print("Mean squared error: %0.4f" % mse)
    
    return {'loss': mse, 'status': STATUS_OK}

# https://towardsdatascience.com/automated-machine-learning-hyperparameter-tuning-in-python-dfda59b72f8a
# set the search space of parameters
hyper_params = {
    "batch_size": hp.quniform("batch_size", batch_size[0], batch_size[1], 1),
    "hidden_units": hp.quniform("hidden_units", hidden_units[0], hidden_units[1], 1),
    "learning_rate": hp.loguniform("learning_rate", np.log(1e-4), np.log(1e-2)),
    "hidden_activation": hp.choice("hidden_activation", hidden_activation),
    "dropout": hp.uniform("dropout", 0.0, 0.5)
}

# store information about trial for sampling configuration
trials = Trials()

# Hyperopt software paper and usage
# # https://conference.scipy.org/proceedings/scipy2013/pdfs/bergstra_hyperopt.pdf
# https://optunity.readthedocs.io/en/latest/user/solvers/TPE.html
# https://medium.com/district-data-labs/parameter-tuning-with-hyperopt-faa86acdfdce
# http://fastml.com/optimizing-hyperparams-with-hyperopt/
# https://medium.com/vooban-ai/hyperopt-tutorial-for-optimizing-neural-networks-hyperparameters-e3102814b919

# get the best parameter configuration
best_parameters = fmin(create_model, hyper_params, trials=trials, algo=tpe.suggest, max_evals=max_evals)

best_model_params = dict()
for item in best_parameters:
    item_val = best_parameters[item]
    if item == 'hidden_activation':
        best_model_params[item] = hidden_activation[item_val]
    else:
        best_model_params[item] = item_val
print(best_model_params)
# Out:
# ==================================================================================
# New model configuration
# ==================================================================================
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_116 (InputLayer)       (None, 9)                 0
# _________________________________________________________________
# dense_314 (Dense)            (None, 71)                710
# _________________________________________________________________
# dropout_167 (Dropout)        (None, 71)                0
# _________________________________________________________________
# dense_315 (Dense)            (None, 71)                5112
# _________________________________________________________________
# dropout_168 (Dropout)        (None, 71)                0
# _________________________________________________________________
# dense_316 (Dense)            (None, 1)                 72
# =================================================================
# Total params: 5,894
# Trainable params: 5,894
# Non-trainable params: 0
# _________________________________________________________________
# Train on 30639 samples, validate on 15091 samples
# Epoch 1/10
#  - 5s - loss: 849434168.7574 - val_loss: 94.7200
#
# Epoch 2/10
#  - 1s - loss: 4455.0601 - val_loss: 77.3802
#
# Epoch 3/10
#  - 1s - loss: 299.8404 - val_loss: 61.1848
#
# Epoch 4/10
#  - 1s - loss: 247.3790 - val_loss: 49.3185
#
# Epoch 5/10
#  - 1s - loss: 138.4288 - val_loss: 41.6940
#
# Epoch 6/10
#  - 1s - loss: 291.0778 - val_loss: 38.3230
#
# Epoch 7/10
#  - 1s - loss: 106.9544 - val_loss: 37.5752
#
# Epoch 8/10
#  - 1s - loss: 76.1695 - val_loss: 37.5603
#
# Epoch 9/10
#  - 1s - loss: 39.8098 - val_loss: 37.5602
#
# Epoch 10/10
#  - 1s - loss: 37.3722 - val_loss: 37.5600
#
# Mean squared error: 37.5600
# ==================================================================================
# New model configuration
# ==================================================================================
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_117 (InputLayer)       (None, 9)                 0
# _________________________________________________________________
# dense_317 (Dense)            (None, 275)               2750
# _________________________________________________________________
# dropout_169 (Dropout)        (None, 275)               0
# _________________________________________________________________
# dense_318 (Dense)            (None, 275)               75900
# _________________________________________________________________
# dropout_170 (Dropout)        (None, 275)               0
# _________________________________________________________________
# dense_319 (Dense)            (None, 1)                 276
# =================================================================
# Total params: 78,926
# Trainable params: 78,926
# Non-trainable params: 0
# _________________________________________________________________
# Train on 30639 samples, validate on 15091 samples
# Epoch 1/10
#  - 7s - loss: 725238945.3125 - val_loss: 395126.3798
#
# Epoch 2/10
#  - 4s - loss: 438698.0763 - val_loss: 77.6936
#
# Epoch 3/10
#  - 4s - loss: 13015.5769 - val_loss: 37.9823
#
# Epoch 4/10
#  - 4s - loss: 6680.2361 - val_loss: 38.3137
#
# Epoch 5/10
#  - 4s - loss: 2527.4112 - val_loss: 37.6508
#
# Epoch 6/10
#  - 4s - loss: 7676.2369 - val_loss: 37.7063
#
# Epoch 7/10
#  - 4s - loss: 6657.6718 - val_loss: 37.5762
#
# Epoch 8/10
#  - 4s - loss: 3316.8995 - val_loss: 37.5725
#
# Epoch 9/10
#  - 4s - loss: 507.8274 - val_loss: 37.5622
#
# Epoch 10/10
#  - 4s - loss: 1818.0048 - val_loss: 37.5622
#
# Mean squared error: 37.5622
# ==================================================================================
# New model configuration
# ==================================================================================
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_118 (InputLayer)       (None, 9)                 0
# _________________________________________________________________
# dense_320 (Dense)            (None, 253)               2530
# _________________________________________________________________
# dropout_171 (Dropout)        (None, 253)               0
# _________________________________________________________________
# dense_321 (Dense)            (None, 253)               64262
# _________________________________________________________________
# dropout_172 (Dropout)        (None, 253)               0
# _________________________________________________________________
# dense_322 (Dense)            (None, 1)                 254
# =================================================================
# Total params: 67,046
# Trainable params: 67,046
# Non-trainable params: 0
# _________________________________________________________________
# Train on 30639 samples, validate on 15091 samples
# Epoch 1/10
#  - 5s - loss: 1475811335.4133 - val_loss: 3376564.7293
#
# Epoch 2/10
#  - 1s - loss: 283866751.3778 - val_loss: 10744172.8701
# Epoch 3/10
#  - 2s - loss: 27371289.9539 - val_loss: 17099.9247
#
# Epoch 4/10
#  - 3s - loss: 142044.5263 - val_loss: 138.4767
#
# Epoch 5/10
#  - 3s - loss: 7172.4702 - val_loss: 92.6748
#
# Epoch 6/10
#  - 2s - loss: 6138.4559 - val_loss: 55.3237
#
# Epoch 7/10
#  - 2s - loss: 4890.7193 - val_loss: 38.3871
#
# Epoch 8/10
#  - 2s - loss: 1223.8302 - val_loss: 37.5784
#
# Epoch 9/10
#  - 3s - loss: 2389.8148 - val_loss: 37.7770
#
# Epoch 10/10
#  - 3s - loss: 814.2599 - val_loss: 37.6354
#
# Mean squared error: 37.6354
# ==================================================================================
# New model configuration
# ==================================================================================
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_119 (InputLayer)       (None, 9)                 0
# _________________________________________________________________
# dense_323 (Dense)            (None, 237)               2370
# _________________________________________________________________
# dropout_173 (Dropout)        (None, 237)               0
# _________________________________________________________________
# dense_324 (Dense)            (None, 237)               56406
# _________________________________________________________________
# dropout_174 (Dropout)        (None, 237)               0
# _________________________________________________________________
# dense_325 (Dense)            (None, 1)                 238
# =================================================================
# Total params: 59,014
# Trainable params: 59,014
# Non-trainable params: 0
# _________________________________________________________________
# Train on 30639 samples, validate on 15091 samples
# Epoch 1/10
#  - 6s - loss: 2820623460.2173 - val_loss: 145440.1383
#
# Epoch 2/10
#  - 1s - loss: 2997202.8177 - val_loss: 155.4336
#
# Epoch 3/10
#  - 1s - loss: 16629.7639 - val_loss: 126.7776
#
# Epoch 4/10
#  - 1s - loss: 6606.3572 - val_loss: 53.0039
#
# Epoch 5/10
#  - 1s - loss: 3726.2707 - val_loss: 38.2920
#
# Epoch 6/10
#  - 1s - loss: 5735.6676 - val_loss: 37.5721
#
# Epoch 7/10
#  - 1s - loss: 1378.6633 - val_loss: 37.5639
#
# Epoch 8/10
#  - 1s - loss: 789.1414 - val_loss: 37.5908
#
# Epoch 9/10
#  - 1s - loss: 177.1160 - val_loss: 37.6941
#
# Mean squared error: 37.6941
# ==================================================================================
# New model configuration
# ==================================================================================
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_120 (InputLayer)       (None, 9)                 0
# _________________________________________________________________
# dense_326 (Dense)            (None, 145)               1450
# _________________________________________________________________
# dropout_175 (Dropout)        (None, 145)               0
# _________________________________________________________________
# dense_327 (Dense)            (None, 145)               21170
# _________________________________________________________________
# dropout_176 (Dropout)        (None, 145)               0
# _________________________________________________________________
# dense_328 (Dense)            (None, 1)                 146
# =================================================================
# Total params: 22,766
# Trainable params: 22,766
# Non-trainable params: 0
# _________________________________________________________________
# Train on 30639 samples, validate on 15091 samples
# Epoch 1/10
#  - 8s - loss: 38.4684 - val_loss: 42.0533
#
# Epoch 2/10
#  - 2s - loss: 38.0751 - val_loss: 38.0169
#
# Epoch 3/10
#  - 2s - loss: 37.9224 - val_loss: 39.1680
#
# Epoch 4/10
#  - 1s - loss: 37.9001 - val_loss: 37.8313
#
# Epoch 5/10
#  - 1s - loss: 37.9207 - val_loss: 41.3895
#
# Epoch 6/10
#  - 1s - loss: 37.8849 - val_loss: 38.5568
#
# Mean squared error: 38.5568
# ==================================================================================
# New model configuration
# ==================================================================================
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_121 (InputLayer)       (None, 9)                 0
# _________________________________________________________________
# dense_329 (Dense)            (None, 209)               2090
# _________________________________________________________________
# dropout_177 (Dropout)        (None, 209)               0
# _________________________________________________________________
# dense_330 (Dense)            (None, 209)               43890
# _________________________________________________________________
# dropout_178 (Dropout)        (None, 209)               0
# _________________________________________________________________
# dense_331 (Dense)            (None, 1)                 210
# =================================================================
# Total params: 46,190
# Trainable params: 46,190
# Non-trainable params: 0
# _________________________________________________________________
# Train on 30639 samples, validate on 15091 samples
# Epoch 1/10
#  - 4s - loss: 38.5431 - val_loss: 37.6511
#
# Epoch 2/10
#  - 1s - loss: 37.8720 - val_loss: 37.5739
#
# Epoch 3/10
#  - 1s - loss: 37.7763 - val_loss: 37.5919
#
# Epoch 4/10
#  - 1s - loss: 37.7316 - val_loss: 37.5962
#
# Mean squared error: 37.5962
# ==================================================================================
# New model configuration
# ==================================================================================
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_122 (InputLayer)       (None, 9)                 0
# _________________________________________________________________
# dense_332 (Dense)            (None, 52)                520
# _________________________________________________________________
# dropout_179 (Dropout)        (None, 52)                0
# _________________________________________________________________
# dense_333 (Dense)            (None, 52)                2756
# _________________________________________________________________
# dropout_180 (Dropout)        (None, 52)                0
# _________________________________________________________________
# dense_334 (Dense)            (None, 1)                 53
# =================================================================
# Total params: 3,329
# Trainable params: 3,329
# Non-trainable params: 0
# _________________________________________________________________
# Train on 30639 samples, validate on 15091 samples
# Epoch 1/10
#  - 6s - loss: 5042123934.7588 - val_loss: 13101.7417
#
# Epoch 2/10
#  - 0s - loss: 11415189.9436 - val_loss: 84.8538
#
# Epoch 3/10
#  - 0s - loss: 142328.1696 - val_loss: 84.2235
#
# Epoch 4/10
#  - 0s - loss: 47900.8134 - val_loss: 81.5401
#
# Epoch 5/10
#  - 0s - loss: 7917.1180 - val_loss: 66.6925
#
# Epoch 6/10
#  - 0s - loss: 10304.2656 - val_loss: 48.8948
#
# Epoch 7/10
#  - 0s - loss: 4578.2519 - val_loss: 38.3382
#
# Epoch 8/10
#  - 0s - loss: 14061.4720 - val_loss: 37.5825
#
# Epoch 9/10
#  - 0s - loss: 24439.2185 - val_loss: 37.5626
#
# Epoch 10/10
#  - 0s - loss: 19923.5081 - val_loss: 37.7211
#
# Mean squared error: 37.7211
# ==================================================================================
# New model configuration
# ==================================================================================
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_123 (InputLayer)       (None, 9)                 0
# _________________________________________________________________
# dense_335 (Dense)            (None, 165)               1650
# _________________________________________________________________
# dropout_181 (Dropout)        (None, 165)               0
# _________________________________________________________________
# dense_336 (Dense)            (None, 165)               27390
# _________________________________________________________________
# dropout_182 (Dropout)        (None, 165)               0
# _________________________________________________________________
# dense_337 (Dense)            (None, 1)                 166
# =================================================================
# Total params: 29,206
# Trainable params: 29,206
# Non-trainable params: 0
# _________________________________________________________________
# Train on 30639 samples, validate on 15091 samples
# Epoch 1/10
#  - 4s - loss: 17531367016.8385 - val_loss: 13082.0416
#
# Epoch 2/10
#  - 1s - loss: 5757381.8872 - val_loss: 97.6833
#
# Epoch 3/10
#  - 1s - loss: 25205.8410 - val_loss: 96.4597
#
# Epoch 4/10
#  - 1s - loss: 29090.2805 - val_loss: 93.7411
#
# Epoch 5/10
#  - 1s - loss: 1695.4363 - val_loss: 90.7930
#
# Epoch 6/10
#  - 1s - loss: 4848.4498 - val_loss: 87.8508
#
# Epoch 7/10
#  - 1s - loss: 23342.6492 - val_loss: 84.6468
# Epoch 8/10
#  - 1s - loss: 32888.2596 - val_loss: 153.3326
#
# Epoch 9/10
#  - 1s - loss: 2458.6671 - val_loss: 80.3441
#
# Epoch 10/10
#  - 1s - loss: 132.3635 - val_loss: 75.7803
#
# Mean squared error: 75.7803
# ==================================================================================
# New model configuration
# ==================================================================================
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_124 (InputLayer)       (None, 9)                 0
# _________________________________________________________________
# dense_338 (Dense)            (None, 38)                380
# _________________________________________________________________
# dropout_183 (Dropout)        (None, 38)                0
# _________________________________________________________________
# dense_339 (Dense)            (None, 38)                1482
# _________________________________________________________________
# dropout_184 (Dropout)        (None, 38)                0
# _________________________________________________________________
# dense_340 (Dense)            (None, 1)                 39
# =================================================================
# Total params: 1,901
# Trainable params: 1,901
# Non-trainable params: 0
# _________________________________________________________________
# Train on 30639 samples, validate on 15091 samples
# Epoch 1/10
#  - 4s - loss: 5538836599.9392 - val_loss: 24345.9688
#
# Epoch 2/10
#  - 1s - loss: 140361.3330 - val_loss: 93.3914
#
# Epoch 3/10
#  - 1s - loss: 5201.0669 - val_loss: 40.7300
#
# Epoch 4/10
#  - 1s - loss: 4173.3797 - val_loss: 37.5995
#
# Epoch 5/10
#  - 1s - loss: 1558.6054 - val_loss: 37.6186
#
# Epoch 6/10
#  - 1s - loss: 220.7348 - val_loss: 37.5612
#
# Epoch 7/10
#  - 1s - loss: 342.0959 - val_loss: 37.5732
#
# Epoch 8/10
#  - 1s - loss: 239.6763 - val_loss: 37.5851
#
# Mean squared error: 37.5851
# ==================================================================================
# New model configuration
# ==================================================================================
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_125 (InputLayer)       (None, 9)                 0
# _________________________________________________________________
# dense_341 (Dense)            (None, 33)                330
# _________________________________________________________________
# dropout_185 (Dropout)        (None, 33)                0
# _________________________________________________________________
# dense_342 (Dense)            (None, 33)                1122
# _________________________________________________________________
# dropout_186 (Dropout)        (None, 33)                0
# _________________________________________________________________
# dense_343 (Dense)            (None, 1)                 34
# =================================================================
# Total params: 1,486
# Trainable params: 1,486
# Non-trainable params: 0
# _________________________________________________________________
# Train on 30639 samples, validate on 15091 samples
# Epoch 1/10
#  - 4s - loss: 28423213293.8772 - val_loss: 8066594.7076
#
# Epoch 2/10
#  - 1s - loss: 1582285581.8427 - val_loss: 18861722.9777
#
# Epoch 3/10
#  - 1s - loss: 520198540.8072 - val_loss: 403962.8109
#
# Epoch 4/10
#  - 1s - loss: 150810452.3300 - val_loss: 292328.1364
#
# Epoch 5/10
#  - 1s - loss: 49129712.2940 - val_loss: 85529.2923
#
# Epoch 6/10
#  - 1s - loss: 21344208.1726 - val_loss: 1203804.7905
#
# Epoch 7/10
#  - 1s - loss: 11069907.5706 - val_loss: 474623.3330
#
# Mean squared error: 474623.3292
# ==================================================================================
# New model configuration
# ==================================================================================
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_126 (InputLayer)       (None, 9)                 0
# _________________________________________________________________
# dense_344 (Dense)            (None, 263)               2630
# _________________________________________________________________
# dropout_187 (Dropout)        (None, 263)               0
# _________________________________________________________________
# dense_345 (Dense)            (None, 263)               69432
# _________________________________________________________________
# dropout_188 (Dropout)        (None, 263)               0
# _________________________________________________________________
# dense_346 (Dense)            (None, 1)                 264
# =================================================================
# Total params: 72,326
# Trainable params: 72,326
# Non-trainable params: 0
# _________________________________________________________________
# Train on 30639 samples, validate on 15091 samples
# Epoch 1/10
#  - 7s - loss: 38.6449 - val_loss: 38.0492
#
# Epoch 2/10
#  - 4s - loss: 38.0146 - val_loss: 38.0027
#
# Epoch 3/10
#  - 4s - loss: 37.9003 - val_loss: 37.6855
#
# Epoch 4/10
#  - 4s - loss: 37.8060 - val_loss: 37.7576
#
# Epoch 5/10
#  - 4s - loss: 37.7919 - val_loss: 37.7427
#
# Mean squared error: 37.7427
# ==================================================================================
# New model configuration
# ==================================================================================
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_127 (InputLayer)       (None, 9)                 0
# _________________________________________________________________
# dense_347 (Dense)            (None, 69)                690
# _________________________________________________________________
# dropout_189 (Dropout)        (None, 69)                0
# _________________________________________________________________
# dense_348 (Dense)            (None, 69)                4830
# _________________________________________________________________
# dropout_190 (Dropout)        (None, 69)                0
# _________________________________________________________________
# dense_349 (Dense)            (None, 1)                 70
# =================================================================
# Total params: 5,590
# Trainable params: 5,590
# Non-trainable params: 0
# _________________________________________________________________
# Train on 30639 samples, validate on 15091 samples
# Epoch 1/10
#  - 5s - loss: 5014587405.6916 - val_loss: 85.5130
#
# Epoch 2/10
#  - 2s - loss: 1009545.3753 - val_loss: 83.1569
#
# Epoch 3/10
#  - 2s - loss: 141257.7179 - val_loss: 67.0534
#
# Epoch 4/10
#  - 2s - loss: 75344.3488 - val_loss: 41.7098
#
# Epoch 5/10
#  - 2s - loss: 50337.3852 - val_loss: 37.8147
#
# Epoch 6/10
#  - 2s - loss: 62187.1462 - val_loss: 38.6995
#
# Epoch 7/10
#  - 2s - loss: 20889.9676 - val_loss: 37.9927
#
# Mean squared error: 37.9927
# ==================================================================================
# New model configuration
# ==================================================================================
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_128 (InputLayer)       (None, 9)                 0
# _________________________________________________________________
# dense_350 (Dense)            (None, 272)               2720
# _________________________________________________________________
# dropout_191 (Dropout)        (None, 272)               0
# _________________________________________________________________
# dense_351 (Dense)            (None, 272)               74256
# _________________________________________________________________
# dropout_192 (Dropout)        (None, 272)               0
# _________________________________________________________________
# dense_352 (Dense)            (None, 1)                 273
# =================================================================
# Total params: 77,249
# Trainable params: 77,249
# Non-trainable params: 0
# _________________________________________________________________
# Train on 30639 samples, validate on 15091 samples
# Epoch 1/10
#  - 4s - loss: 29398322682.9502 - val_loss: 35917.2626
#
# Epoch 2/10
#  - 1s - loss: 1004283.0241 - val_loss: 71.3348
#
# Epoch 3/10
#  - 1s - loss: 8870.7881 - val_loss: 37.5817
#
# Epoch 4/10
#  - 1s - loss: 880.9667 - val_loss: 37.5647
#
# Epoch 5/10
#  - 1s - loss: 3847.0500 - val_loss: 37.5621
#
# Epoch 6/10
#  - 1s - loss: 1713.1678 - val_loss: 37.8329
#
# Epoch 7/10
#  - 1s - loss: 505.9709 - val_loss: 37.8975
#
# Mean squared error: 37.8975
# ==================================================================================
# New model configuration
# ==================================================================================
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_129 (InputLayer)       (None, 9)                 0
# _________________________________________________________________
# dense_353 (Dense)            (None, 236)               2360
# _________________________________________________________________
# dropout_193 (Dropout)        (None, 236)               0
# _________________________________________________________________
# dense_354 (Dense)            (None, 236)               55932
# _________________________________________________________________
# dropout_194 (Dropout)        (None, 236)               0
# _________________________________________________________________
# dense_355 (Dense)            (None, 1)                 237
# =================================================================
# Total params: 58,529
# Trainable params: 58,529
# Non-trainable params: 0
# _________________________________________________________________
# Train on 30639 samples, validate on 15091 samples
# Epoch 1/10
#  - 4s - loss: 38.6395 - val_loss: 37.8893
#
# Epoch 2/10
#  - 1s - loss: 37.8079 - val_loss: 37.8775
#
# Epoch 3/10
#  - 1s - loss: 37.7037 - val_loss: 37.6626
#
# Epoch 4/10
#  - 1s - loss: 37.6909 - val_loss: 37.5863
#
# Epoch 5/10
#  - 1s - loss: 37.6795 - val_loss: 37.7297
#
# Epoch 6/10
#  - 1s - loss: 37.6340 - val_loss: 37.5834
#
# Epoch 7/10
#  - 1s - loss: 37.5927 - val_loss: 37.8875
#
# Epoch 8/10
#  - 1s - loss: 37.6363 - val_loss: 37.7037
#
# Mean squared error: 37.7037
# ==================================================================================
# New model configuration
# ==================================================================================
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_130 (InputLayer)       (None, 9)                 0
# _________________________________________________________________
# dense_356 (Dense)            (None, 30)                300
# _________________________________________________________________
# dropout_195 (Dropout)        (None, 30)                0
# _________________________________________________________________
# dense_357 (Dense)            (None, 30)                930
# _________________________________________________________________
# dropout_196 (Dropout)        (None, 30)                0
# _________________________________________________________________
# dense_358 (Dense)            (None, 1)                 31
# =================================================================
# Total params: 1,261
# Trainable params: 1,261
# Non-trainable params: 0
# _________________________________________________________________
# Train on 30639 samples, validate on 15091 samples
# Epoch 1/10
#  - 4s - loss: 50.4966 - val_loss: 37.5679
#
# Epoch 2/10
#  - 0s - loss: 37.7473 - val_loss: 37.5645
#
# Epoch 3/10
#  - 0s - loss: 37.7446 - val_loss: 37.5627
#
# Epoch 4/10
#  - 0s - loss: 37.7370 - val_loss: 37.5673
#
# Epoch 5/10
#  - 0s - loss: 37.6667 - val_loss: 37.5630
#
# Mean squared error: 37.5630
# ==================================================================================
# New model configuration
# ==================================================================================
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_131 (InputLayer)       (None, 9)                 0
# _________________________________________________________________
# dense_359 (Dense)            (None, 152)               1520
# _________________________________________________________________
# dropout_197 (Dropout)        (None, 152)               0
# _________________________________________________________________
# dense_360 (Dense)            (None, 152)               23256
# _________________________________________________________________
# dropout_198 (Dropout)        (None, 152)               0
# _________________________________________________________________
# dense_361 (Dense)            (None, 1)                 153
# =================================================================
# Total params: 24,929
# Trainable params: 24,929
# Non-trainable params: 0
# _________________________________________________________________
# Train on 30639 samples, validate on 15091 samples
# Epoch 1/10
#  - 4s - loss: 39.0215 - val_loss: 37.5760
#
# Epoch 2/10
#  - 1s - loss: 38.1105 - val_loss: 37.7562
#
# Epoch 3/10
#  - 1s - loss: 38.0344 - val_loss: 37.5656
#
# Epoch 4/10
#  - 1s - loss: 37.9414 - val_loss: 38.6401
#
# Epoch 5/10
#  - 1s - loss: 37.8937 - val_loss: 37.5756
#
# Mean squared error: 37.5756
# ==================================================================================
# New model configuration
# ==================================================================================
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_132 (InputLayer)       (None, 9)                 0
# _________________________________________________________________
# dense_362 (Dense)            (None, 67)                670
# _________________________________________________________________
# dropout_199 (Dropout)        (None, 67)                0
# _________________________________________________________________
# dense_363 (Dense)            (None, 67)                4556
# _________________________________________________________________
# dropout_200 (Dropout)        (None, 67)                0
# _________________________________________________________________
# dense_364 (Dense)            (None, 1)                 68
# =================================================================
# Total params: 5,294
# Trainable params: 5,294
# Non-trainable params: 0
# _________________________________________________________________
# Train on 30639 samples, validate on 15091 samples
# Epoch 1/10
#  - 4s - loss: 1727207332.3034 - val_loss: 89.5179
#
# Epoch 2/10
#  - 1s - loss: 27449.2428 - val_loss: 62.4624
#
# Epoch 3/10
#  - 1s - loss: 7652.7765 - val_loss: 38.1392
#
# Epoch 4/10
#  - 1s - loss: 7690.0360 - val_loss: 37.8197
#
# Epoch 5/10
#  - 1s - loss: 3732.6636 - val_loss: 37.6608
#
# Epoch 6/10
#  - 1s - loss: 12768.1428 - val_loss: 37.5924
#
# Epoch 7/10
#  - 1s - loss: 326.9196 - val_loss: 37.5771
#
# Epoch 8/10
#  - 1s - loss: 341.8305 - val_loss: 37.6679
#
# Epoch 9/10
#  - 1s - loss: 859.7071 - val_loss: 38.1030
#
# Mean squared error: 38.1030
# ==================================================================================
# New model configuration
# ==================================================================================
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_133 (InputLayer)       (None, 9)                 0
# _________________________________________________________________
# dense_365 (Dense)            (None, 145)               1450
# _________________________________________________________________
# dropout_201 (Dropout)        (None, 145)               0
# _________________________________________________________________
# dense_366 (Dense)            (None, 145)               21170
# _________________________________________________________________
# dropout_202 (Dropout)        (None, 145)               0
# _________________________________________________________________
# dense_367 (Dense)            (None, 1)                 146
# =================================================================
# Total params: 22,766
# Trainable params: 22,766
# Non-trainable params: 0
# _________________________________________________________________
# Train on 30639 samples, validate on 15091 samples
# Epoch 1/10
#  - 5s - loss: 2145041589.2118 - val_loss: 97.3040
#
# Epoch 2/10
#  - 1s - loss: 39654.3334 - val_loss: 92.0037
#
# Epoch 3/10
#  - 1s - loss: 6350.1858 - val_loss: 84.7178
#
# Epoch 4/10
#  - 1s - loss: 5789.6366 - val_loss: 77.7372
#
# Epoch 5/10
#  - 1s - loss: 2115.1984 - val_loss: 70.7666
#
# Epoch 6/10
#  - 1s - loss: 5206.4230 - val_loss: 64.8738
#
# Epoch 7/10
#  - 1s - loss: 597.8830 - val_loss: 58.7218
#
# Epoch 8/10
#  - 1s - loss: 2061.8867 - val_loss: 53.9242
#
# Epoch 9/10
#  - 1s - loss: 268.1996 - val_loss: 49.3571
#
# Epoch 10/10
#  - 1s - loss: 879.4481 - val_loss: 45.8812
#
# Mean squared error: 45.8812
# ==================================================================================
# New model configuration
# ==================================================================================
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_134 (InputLayer)       (None, 9)                 0
# _________________________________________________________________
# dense_368 (Dense)            (None, 262)               2620
# _________________________________________________________________
# dropout_203 (Dropout)        (None, 262)               0
# _________________________________________________________________
# dense_369 (Dense)            (None, 262)               68906
# _________________________________________________________________
# dropout_204 (Dropout)        (None, 262)               0
# _________________________________________________________________
# dense_370 (Dense)            (None, 1)                 263
# =================================================================
# Total params: 71,789
# Trainable params: 71,789
# Non-trainable params: 0
# _________________________________________________________________
# Train on 30639 samples, validate on 15091 samples
# Epoch 1/10
#  - 5s - loss: 38.7551 - val_loss: 37.9862
#
# Epoch 2/10
#  - 1s - loss: 37.7580 - val_loss: 37.5605
#
# Epoch 3/10
#  - 1s - loss: 37.6809 - val_loss: 37.5601
#
# Epoch 4/10
#  - 1s - loss: 37.7380 - val_loss: 37.5616
#
# Epoch 5/10
#  - 1s - loss: 37.7072 - val_loss: 37.5683
#
# Mean squared error: 37.5683
# ==================================================================================
# New model configuration
# ==================================================================================
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_135 (InputLayer)       (None, 9)                 0
# _________________________________________________________________
# dense_371 (Dense)            (None, 130)               1300
# _________________________________________________________________
# dropout_205 (Dropout)        (None, 130)               0
# _________________________________________________________________
# dense_372 (Dense)            (None, 130)               17030
# _________________________________________________________________
# dropout_206 (Dropout)        (None, 130)               0
# _________________________________________________________________
# dense_373 (Dense)            (None, 1)                 131
# =================================================================
# Total params: 18,461
# Trainable params: 18,461
# Non-trainable params: 0
# _________________________________________________________________
# Train on 30639 samples, validate on 15091 samples
# Epoch 1/10
#  - 5s - loss: 40.4021 - val_loss: 38.4093
#
# Epoch 2/10
#  - 1s - loss: 37.7943 - val_loss: 37.6616
#
# Epoch 3/10
#  - 1s - loss: 37.7030 - val_loss: 37.5599
#
# Epoch 4/10
#  - 1s - loss: 37.6348 - val_loss: 37.5603
#
# Epoch 5/10
#  - 1s - loss: 37.6565 - val_loss: 37.9592
#
# Mean squared error: 37.9592
# 100%|██████████| 20/20 [05:19<00:00, 12.44s/it, best loss: 37.559956349997236]
# {'batch_size': 120.0, 'dropout': 0.29013369549032786, 'hidden_activation': 'relu', 'hidden_units': 71.0, 'learning_rate': 0.005946677171602024}

# %%
# Plot the optimization results

import matplotlib.pyplot as plt


f_size = 18

def plot_classification_param(key, xlabel):
    plt.figure(figsize=(10,10))
    xs = [t['misc']['vals'][key] for t in trials.trials]
    ys = [t['result']['loss'] for t in trials.trials if t['result']['loss']]
    y_val = list()
    x_val = list()
    for index, item in enumerate(ys):
        if item < 10000:
            y_val.append(item)
            x_val.append(xs[index])
    plt.scatter(x_val, y_val, s=50, linewidth=0.1, alpha=0.5, color='red')
    plt.title('Regression: Protein Tertiary Structure', fontsize=f_size)
    plt.xlabel(xlabel, fontsize=f_size)
    plt.ylabel('Mean squared error', fontsize=f_size)
    plt.grid(True)
    plt.show()

# %%
plot_classification_param('batch_size', 'Batch size')

# %%
plot_classification_param('learning_rate', 'Learning rate')

# %%
plot_classification_param('hidden_units', 'Number of hidden units')

# %%
plot_classification_param('dropout', 'Dropout')
